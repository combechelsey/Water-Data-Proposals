# %% [markdown]
# <a href="https://colab.research.google.com/github/combechelsey/Water-Data-Proposals/blob/main/Project_2_Proposals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Summary of 2 Potential Datasets for Machine Learning**
# ###Chelsey Combe

# %%
#Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #**Full Scale Waste Water Treatment Plant Data**

# %% [markdown]
# 1. Source of data
#   - Kaggle.  Data originally sourced from a wastewater treatment plant in Melbourne, Australia a well as open access data by Melbourne weather stations.
#
#   - url:  https://www.kaggle.com/datasets/d4rklucif3r/full-scale-waste-water-treatment-plant-data
#
# 2. Brief description of data
#
#   - Energy consumption, climate, and wastewater characteristics of Melbourne eastern wastewater treatment plant for preiod of six years (2014-2019).
#
#   - Sources for data: "This dataset is a combination (inner join) of open access data produced by Melbourne water and Melbourne airport weather station. Power consumption, Hydraulic, biological, and climate data are merged by the record date column (day/month/year)."
#
# 3. What is the target?
#
#   - Regression Problem--Analzye the outflow of the wastewater treatment plant following treatment.
#
# 4. What does one row represent? (A person? A business? An event? A product?)
#
#   - Water quality, contaminants, and biologial oxygen requirements for treatment.
#
# 5. Is this a classification or regression problem?
#
#   - Regression--Outflow
#
# 6. How many features does the data have?
#   - 20 Features
#
# 7. How many rows are in the dataset?
#   - 1382 Rows
#
# 8. What, if any, challenges do you foresee in cleaning, exploring, or modeling this dataset?
#
#   - Is the dataset large enough for reliable prediction?

# %%
https://www.kaggle.com/datasets/d4rklucif3r/full-scale-waste-water-treatment-plant-data

# %%
#Loading dataset
file_path = "/content/drive/MyDrive/CodingDojo/02-MachineLearning/Week08/Data/Data-Melbourne_F.csv"
df = pd.read_csv(file_path)
df.head(30)
# Out:
#     avg_outflow  avg_inflow  total_grid    Am    BOD     COD      TN     T  \
# 0         2.941       2.589      175856  27.0  365.0   730.0  60.378  19.3
# 1         2.936       2.961      181624  25.0  370.0   740.0  60.026  17.1
# 2         2.928       3.225      202016  42.0  418.0   836.0  64.522  16.8
# 3         2.928       3.354      207547  36.0  430.0   850.0  63.000  14.6
# 4         2.917       3.794      202824  46.0  508.0  1016.0  65.590  13.4
# 5         2.912       3.750      247691  40.0  410.0   820.0  61.786  18.9
# 6         2.355       3.507      224706  51.0  555.0  1110.0  68.820  25.9
# 7         2.366       3.188      212440  41.0  365.0   730.0  62.218  17.7
# 8         3.923       3.378      202676  26.0  355.0   710.0  61.433  26.4
# 9         3.912       3.425      202411  42.0  530.0   830.0  66.354  35.5
# 10        2.971       3.775      171123  47.0  435.0   870.0  65.531  32.1
# ...

# %%
df.shape
# Out:
# (1382, 20)

# %% [markdown]
# #**Drinking_Water_Potability**

# %% [markdown]
# Contaminated water and poor sanitation are linked to the transmission of diseases such as cholera, diarrhea, dysentery, hepatitis A, typhoid, and polio. Absent, inadequate, or inappropriately managed water and sanitation services expose individuals to preventable health risks. This is particularly the case in health care facilities where both patients and staff are placed at additional risk of infection and disease when water, sanitation, and hygiene services are lacking.

# %% [markdown]
# 1. Source of data
#   - Kaggle.  Water Quality Data
#
#   - url:  1. Source of data
#
#   - url:  https://www.kaggle.com/datasets/d4rklucif3r/full-scale-waste-water-treatment-plant-data
#
# 2. Brief description of data
#
#   - Water Quality and COntaninant data for the purpose of determining suitability for human consumption.
#
# 3. What is the target?
#
#   - Classification problem - Potable or non-potalbe water.
#
# 4. What does one row represent? (A person? A business? An event? A product?)
#
#   - Ph, hardness, sulfates, carbon.
#
# 5. Is this a classification or regression problem?
#
#   - Classification
#
# 6. How many features does the data have?
#   - 10 Features
#
# 7. How many rows are in the dataset?
#   - 3276 Rows
#
# 8. What, if any, challenges do you foresee in cleaning, exploring, or modeling this dataset?
#
#   - I have not found the original source of the data yet.
#
#
#   - 1382 Rows

# %% [markdown]
# https://www.kaggle.com/datasets/artimule/drinking-water-probability

# %%
#Loading dataset
file_path = "/content/drive/MyDrive/CodingDojo/02-MachineLearning/Week08/Data/drinking_water_potability.csv"
df = pd.read_csv(file_path)
df.head(30)
# Out:
#            ph    Hardness       Solids  Chloramines     Sulfate  Conductivity  \
# 0         NaN  204.890456  20791.31898     7.300212  368.516441    564.308654
# 1    3.716080  129.422921  18630.05786     6.635246         NaN    592.885359
# 2    8.099124  224.236259  19909.54173     9.275884         NaN    418.606213
# 3    8.316766  214.373394  22018.41744     8.059332  356.886136    363.266516
# 4    9.092223  181.101509  17978.98634     6.546600  310.135738    398.410813
# 5    5.584087  188.313324  28748.68774     7.544869  326.678363    280.467916
# 6   10.223862  248.071735  28749.71654     7.513408  393.663395    283.651634
# 7    8.635849  203.361523  13672.09176     4.563009  303.309771    474.607645
# 8         NaN  118.988579  14285.58385     7.804174  268.646941    389.375566
# 9   11.180284  227.231469  25484.50849     9.077200  404.041635    563.885481
# 10   7.360640  165.520797  32452.61441     7.550701  326.624353    425.383420
# ...

# %%
df.shape
# Out:
# (3276, 10)
